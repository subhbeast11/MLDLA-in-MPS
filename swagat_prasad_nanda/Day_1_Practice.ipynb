# %% [markdown]
# # "Machine Learning \& Deep Learning Applications in Modern Power Systems"
# ## Department of Electrical Engineering - PMEC, Berhampur
# ### Instructor: Dr. Suryalok Dash

# %% [markdown]
# # Day 1: Exercise Notebook
# **Task:** Complete the missing code sections marked with `### YOUR CODE HERE ###`.

# %%
# Task 1: Create a function that checks if a voltage is within acceptable limits.
# Nominal voltage is 230V. Acceptable range is 207V to 253V.

def check_voltage(v):

    ### YOUR CODE HERE ###

    # Return "Normal" if v is between 207 and 253, else return "Anomaly"
    pass

# Test your function
print(check_voltage(240)) # Should print Normal
print(check_voltage(190)) # Should print Anomaly
# Out:
# Normal
# Anomaly

# %%
# Task 2: Find buses with undervoltage (< 0.95 p.u.)
bus_voltages_pu = {"Bus1": 1.0, "Bus2": 0.92, "Bus3": 0.98, "Bus4": 0.91}

undervoltage_buses = []

### YOUR CODE HERE ###

# Hint: Iterate through the dictionary and append bus names with voltage < 0.95 to the list

print("Undervoltage Buses:", undervoltage_buses)

# %%
import numpy as np

# You are given a NumPy array representing solar power generation in kW over 5 hours.
solar_generation = np.array([0.5, 1.2, 3.4, 4.1, 2.8])

# Task 3: Calculate the total energy generated.
total_energy = ### YOUR CODE HERE ###
print("Total Energy:", total_energy)

# Task 4: Find the maximum power output.
peak_power = ### YOUR CODE HERE ###
print("Peak Power:", peak_power)

# Task 5: The sensor had a 10% calibration error. Multiply the array by 1.1 to correct it.
corrected_generation = ### YOUR CODE HERE ###
print("Corrected Generation:", corrected_generation)

# %%
# Task 6: Extract the load values from hours 18 to 21 (indices 17 to 20) from this 24-hour load array.
daily_load_mw = np.array([10, 11, 10, 9, 9, 12, 15, 18, 20, 22, 23, 22, 21, 20, 19, 18, 20, 25, 28, 27, 24, 20, 15, 12])

evening_peak = ### YOUR CODE HERE ###
print("Evening Peak Load (MW):", evening_peak)

# Task 7: Find the index (hour) of the absolute maximum load in the array.
peak_hour_index = ### YOUR CODE HERE ###
print("Peak Hour Index:", peak_hour_index)
